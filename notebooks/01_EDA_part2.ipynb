# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns 

from src.config import DADOS_CONSOLIDADOS, DADOS_TRATADOS

sns.set_theme(palette='bright')

# %%
df = pd.read_parquet(DADOS_CONSOLIDADOS)

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4           A4         X            9.2               7.2
# 1          4           M5         X            9.1               7.3
# 2          6           A5         Z           15.9              11.1
# 3          6          AS4         Z           15.1              10.5
# 4          6           M6         Z           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21214 entries, 0 to 21213
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model_year          21214 non-null  int64
#  1   make                21214 non-null  object
#  2   model               21214 non-null  object
#  3   vehicle_class       21214 non-null  object
#  4   engine_size_l       21214 non-null  float64
#  5   cylinders           21214 non-null  int64
#  6   transmission        21214 non-null  object
#  7   fuel_type           21214 non-null  object
#  8   city_l_100_km       21214 non-null  float64
#  9   highway_l_100_km    21214 non-null  float64
#  10  combined_l_100_km   21214 non-null  float64
#  11  combined_mpg        21214 non-null  int64
#  12  co2_emissions_g_km  21214 non-null  int64
#  13  co2_rating          9525 non-null   float64
#  14  smog_rating         8419 non-null   float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 2.4+ MB

# %%
with pd.option_context('display.float_format', '{:.2f}'.format):
    display(df.describe())
# Out:
#        model_year  engine_size_l  cylinders  city_l_100_km  highway_l_100_km  \
# count    21214.00       21214.00   21214.00       21214.00          21214.00
# mean      2014.60           3.33       5.81          13.39              9.70
# std          5.82           1.35       1.87           3.78              2.51
# min       2005.00           0.80       2.00           4.00              3.90
# 25%       2010.00           2.00       4.00          10.80              8.00
# 50%       2015.00           3.00       6.00          12.90              9.30
# 75%       2019.00           4.00       8.00          15.50             11.00
# max       2025.00           8.40      16.00          30.70             22.10
#
#        combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# count           21214.00      21214.00            21214.00     9525.00
# mean               11.73         25.82              266.40        4.62
# std                 3.17          7.07               63.58        1.56
# min                 4.00         11.00               94.00        1.00
# 25%                 9.50         21.00              221.00        4.00
# 50%                11.30         25.00              261.00        5.00
# 75%                13.40         30.00              304.00        5.00
# max                26.10         71.00              608.00       10.00
#
#        smog_rating
# count      8419.00
# mean          4.83
# std           1.75
# min           1.00
# 25%           3.00
# 50%           5.00
# 75%           6.00
# max           8.00

# %%
df.describe(exclude='number')
# Out:
#              make    model vehicle_class transmission fuel_type
# count       21214    21214         21214        21214     21214
# unique         48     3609            17           29         5
# top     Chevrolet  Mustang      Mid-size          AS6         X
# freq         1929       99          2803         2899     10479

# %%
# A transmissão é uma combinação entre tipo de transmissão e número de marchas (vide dicionário de dados) 
# Portanto, faz sentido separar essa informações visando reduzir a dimenssão da base quando efetuado o OneHotEncoding
df['gears'] = df['transmission'].str.extract(r"(\d+)").astype('float')

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4           A4         X            9.2               7.2
# 1          4           M5         X            9.1               7.3
# 2          6           A5         Z           15.9              11.1
# 3          6          AS4         Z           15.1              10.5
# 4          6           M6         Z           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating  gears
# 0          NaN    4.0
# 1          NaN    5.0
# 2          NaN    5.0
# 3          NaN    4.0
# 4          NaN    6.0

# %%
df['transmission'] = df['transmission'].str.replace(r"(\d+)", '', regex=True)
df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4            A         X            9.2               7.2
# 1          4            M         X            9.1               7.3
# 2          6            A         Z           15.9              11.1
# 3          6           AS         Z           15.1              10.5
# 4          6            M         Z           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating  gears
# 0          NaN    4.0
# 1          NaN    5.0
# 2          NaN    5.0
# 3          NaN    4.0
# 4          NaN    6.0

# %%
df.describe(exclude='number')
# Out:
#              make    model vehicle_class transmission fuel_type
# count       21214    21214         21214        21214     21214
# unique         48     3609            17            5         5
# top     Chevrolet  Mustang      Mid-size           AS         X
# freq         1929       99          2803         7486     10479

# %%
# Substituindo os valores de combustível para facilitar a interpretação dos gráficos
fuel = {
    'X': 'reg_gasoline',
    'Z': 'premium_gasoline',
    'D': 'diesel',
    'E': 'ethanol',
    'N': 'natural_gas',
}

df['fuel_type'] = df['fuel_type'].map(fuel)

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission         fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4            A      reg_gasoline            9.2               7.2
# 1          4            M      reg_gasoline            9.1               7.3
# 2          6            A  premium_gasoline           15.9              11.1
# 3          6           AS  premium_gasoline           15.1              10.5
# 4          6            M  premium_gasoline           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating  gears
# 0          NaN    4.0
# 1          NaN    5.0
# 2          NaN    5.0
# 3          NaN    4.0
# 4          NaN    6.0

# %%
df[df == 0].count()
# Out:
# model_year            0
# make                  0
# model                 0
# vehicle_class         0
# engine_size_l         0
# cylinders             0
# transmission          0
# fuel_type             0
# city_l_100_km         0
# highway_l_100_km      0
# combined_l_100_km     0
# combined_mpg          0
# co2_emissions_g_km    0
# co2_rating            0
# smog_rating           0
# gears                 0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# model_year                0
# make                      0
# model                     0
# vehicle_class             0
# engine_size_l             0
# cylinders                 0
# transmission              0
# fuel_type                 0
# city_l_100_km             0
# highway_l_100_km          0
# combined_l_100_km         0
# combined_mpg              0
# co2_emissions_g_km        0
# co2_rating            11689
# smog_rating           12795
# gears                   913
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Como temos uma alta cardinalidade na coluna "model" pode não ser tão interessante para o algoritmo captar informações relevantes
# Em relação ao 'combined_mpg' é apenas uma conversão da coluna "combined_l_100_km", ou seja, informação duplicada aumentando o peso de uma informação para o algoritmo
df = df.drop(columns=['combined_mpg', 'model'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21214 entries, 0 to 21213
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model_year          21214 non-null  int64
#  1   make                21214 non-null  object
#  2   vehicle_class       21214 non-null  object
#  3   engine_size_l       21214 non-null  float64
#  4   cylinders           21214 non-null  int64
#  5   transmission        21214 non-null  object
#  6   fuel_type           21214 non-null  object
#  7   city_l_100_km       21214 non-null  float64
#  8   highway_l_100_km    21214 non-null  float64
#  9   combined_l_100_km   21214 non-null  float64
#  10  co2_emissions_g_km  21214 non-null  int64
#  11  co2_rating          9525 non-null   float64
#  12  smog_rating         8419 non-null   float64
#  13  gears               20301 non-null  float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 2.3+ MB

# %%
df.nunique()
# Out:
# model_year             21
# make                   48
# vehicle_class          17
# engine_size_l          61
# cylinders               9
# transmission            5
# fuel_type               5
# city_l_100_km         238
# highway_l_100_km      168
# combined_l_100_km     207
# co2_emissions_g_km    376
# co2_rating             10
# smog_rating             8
# gears                   8
# dtype: int64

# %%
df['make'].value_counts()
# Out:
# make
# Chevrolet        1929
# Ford             1585
# BMW              1415
# Mercedes-Benz    1248
# GMC              1210
# Porsche          1056
# Toyota            959
# Audi              819
# Dodge             748
# Nissan            705
# Volkswagen        597
# Hyundai           564
# Jeep              562
# Kia               549
# Mazda             545
# Honda             541
# Lexus             492
# Cadillac          477
# Subaru            472
# MINI              453
# Volvo             426
# Jaguar            342
# Chrysler          327
# Mitsubishi        297
# Land Rover        263
# Infiniti          262
# Buick             248
# Acura             221
# Lincoln           210
# Ram               171
# Maserati          160
# Pontiac           158
# Bentley           129
# Suzuki            127
# Lamborghini       123
# Rolls-Royce       123
# Aston Martin      122
# Saab              115
# FIAT               86
# Saturn             83
# Genesis            70
# Alfa Romeo         60
# Ferrari            57
# Scion              44
# smart              22
# Hummer             21
# Bugatti            17
# SRT                 4
# Name: count, dtype: int64

# %%
categoricas = df.select_dtypes(include='object').columns.to_list()
categoricas.extend(['model_year', 'cylinders', 'gears'])
categoricas
# Out:
# ['make',
#  'vehicle_class',
#  'transmission',
#  'fuel_type',
#  'model_year',
#  'cylinders',
#  'gears']

# %%
fig, axs = plt.subplots(7,1, figsize=(10, 40))

for ax, coluna in zip(axs.flatten(), categoricas):
    sns.countplot(
        data=df,
        x=coluna,
        order=df[coluna].value_counts().index[:20],
        ax=ax,
    )
    ax.bar_label(ax.containers[0])
    ax.tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
# A transmissão AV chama atenção em relação número de marchas ser igual a 1. Nesse caso não faz muito sentido já que é um câmbio sequencial
df[df['gears'] == 1]
# Out:
#        model_year     make                 vehicle_class  engine_size_l  \
# 17419        2021  Hyundai                      Mid-size            2.0
# 17420        2021  Hyundai                      Mid-size            2.0
# 17443        2021  Hyundai                      Mid-size            1.6
# 17512        2021      Kia                       Compact            1.6
# 18394        2022  Hyundai                      Mid-size            2.0
# 18395        2022  Hyundai                      Mid-size            2.0
# 18421        2022  Hyundai                      Mid-size            1.6
# 18490        2022      Kia                       Compact            1.6
# 19326        2023  Hyundai                      Mid-size            2.0
# 19327        2023  Hyundai                      Mid-size            2.0
# 19347        2023  Hyundai                      Mid-size            1.6
# 19405        2023      Kia                       Compact            1.6
# 20093        2024  Hyundai                      Mid-size            2.0
# 20094        2024  Hyundai                      Mid-size            2.0
# 20098        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20099        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20101        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20102        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20114        2024  Hyundai  Sport utility vehicle: Small            1.6
# 20830        2025  Hyundai                      Mid-size            2.0
# 20831        2025  Hyundai                      Mid-size            2.0
# 20835        2025  Hyundai  Sport utility vehicle: Small            2.0
# 20836        2025  Hyundai  Sport utility vehicle: Small            2.0
# 20838        2025  Hyundai  Sport utility vehicle: Small            2.0
# 20839        2025  Hyundai  Sport utility vehicle: Small            2.0
# 20852        2025  Hyundai  Sport utility vehicle: Small            1.6
# 20876        2025      Kia                      Mid-size            2.0
# 20877        2025      Kia                      Mid-size            2.0
#
#        cylinders transmission     fuel_type  city_l_100_km  highway_l_100_km  \
# 17419          4           AV  reg_gasoline            7.5               5.7
# 17420          4           AV  reg_gasoline            7.1               5.5
# 17443          4           AV  reg_gasoline            7.9               7.0
# 17512          4           AV  reg_gasoline            7.2               6.0
# 18394          4           AV  reg_gasoline            7.6               5.7
# 18395          4           AV  reg_gasoline            7.1               5.5
# 18421          4           AV  reg_gasoline            7.9               6.9
# 18490          4           AV  reg_gasoline            7.2               6.0
# 19326          4           AV  reg_gasoline            7.6               5.7
# 19327          4           AV  reg_gasoline            7.1               5.5
# 19347          4           AV  reg_gasoline            7.9               6.9
# 19405          4           AV  reg_gasoline            7.2               6.1
# 20093          4           AV  reg_gasoline            7.6               5.9
# 20094          4           AV  reg_gasoline            7.3               5.7
# 20098          4           AV  reg_gasoline            8.4               6.7
# 20099          4           AV  reg_gasoline            8.1               6.8
# 20101          4           AV  reg_gasoline            9.0               8.1
# 20102          4           AV  reg_gasoline            8.8               8.1
# 20114          4           AV  reg_gasoline            7.9               6.9
# 20830          4           AV  reg_gasoline            7.7               5.9
# 20831          4           AV  reg_gasoline            7.3               5.7
# 20835          4           AV  reg_gasoline            8.4               6.7
# 20836          4           AV  reg_gasoline            8.1               6.8
# 20838          4           AV  reg_gasoline            9.0               8.1
# 20839          4           AV  reg_gasoline            8.8               8.1
# 20852          4           AV  reg_gasoline            7.9               6.9
# 20876          4           AV  reg_gasoline            8.4               6.0
# 20877          4           AV  reg_gasoline            7.9               5.8
#
#        combined_l_100_km  co2_emissions_g_km  co2_rating  smog_rating  gears
# 17419                6.7                 157         7.0          5.0    1.0
# 17420                6.4                 152         8.0          5.0    1.0
# 17443                7.5                 178         7.0          5.0    1.0
# 17512                6.7                 159         7.0          3.0    1.0
# 18394                6.7                 158         7.0          5.0    1.0
# 18395                6.4                 151         7.0          5.0    1.0
# 18421                7.5                 176         7.0          5.0    1.0
# 18490                6.7                 159         7.0          3.0    1.0
# 19326                6.7                 158         7.0          5.0    1.0
# 19327                6.4                 151         7.0          5.0    1.0
# 19347                7.5                 177         6.0          5.0    1.0
# 19405                6.7                 160         7.0          3.0    1.0
# 20093                6.8                 160         7.0          7.0    1.0
# 20094                6.5                 153         7.0          7.0    1.0
# 20098                7.6                 179         6.0          7.0    1.0
# 20099                7.5                 177         6.0          7.0    1.0
# 20101                8.6                 201         6.0          7.0    1.0
# 20102                8.5                 198         6.0          7.0    1.0
# 20114                7.5                 177         6.0          5.0    1.0
# 20830                6.9                 160         7.0          6.0    1.0
# 20831                6.5                 153         7.0          6.0    1.0
# 20835                7.6                 179         6.0          6.0    1.0
# 20836                7.5                 177         6.0          6.0    1.0
# 20838                8.6                 201         6.0          6.0    1.0
# 20839                8.5                 198         6.0          6.0    1.0
# 20852                7.5                 177         6.0          4.0    1.0
# 20876                7.3                 172         6.0          6.0    1.0
# 20877                7.0                 164         7.0          6.0    1.0

# %%
pd.crosstab(df['gears'], df['transmission'], dropna=False)
# Como podemos observar, possui algumas inconsistências cadastrais tanto em valores vazios, quanto em valores que fazem sentido para um câmbio.
# No momento do preenchimento, algumas pessoas podem ter colocado o número de marchas que esse câmbio simula, e outras pessoas deixaram o número de marchas ora vazio, ora com valor 1
# Já que na prática ele é uma transmissão contínua
# Out:
# transmission     A   AM    AS   AV     M
# gears
# 1.0              0    0     0   28     0
# 4.0           1850    0   162    0     1
# 5.0            889    6   673    0  1165
# 6.0           1946  223  2899  171  2561
# 7.0            276  850   621  160   154
# 8.0           1048  267  2382  145     0
# 9.0            699    6   182    0     0
# 10.0           324    0   567   46     0
# NaN              0    0     0  913     0

# %%
fig, axs = plt.subplots(2, 5, figsize=(20,10))

for ax, coluna in zip(axs.flatten(), df.select_dtypes('number').columns):
    sns.histplot(data=df, x=coluna, ax=ax, kde=True)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 5, figsize=(20,10))

for ax, coluna in zip(axs.flatten(), df.select_dtypes('number').columns):
    sns.boxplot(data=df, x=coluna, ax=ax, showmeans=True)

plt.tight_layout()
plt.show()

# %%
corr = df.select_dtypes('number').corr()
matriz = np.triu(corr)

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(
    corr,
    mask=matriz,
    annot=True,
    fmt='.2f',
    ax=ax,
    annot_kws={'fontsize': 8},
    cmap='coolwarm'
)

plt.show()

# %%
co2_latex = r'CO$_2$'

fig, ax = plt.subplots(figsize=(12, 6))

# Gráfico
sns.barplot(
    data=df,
    x='make',
    y='co2_emissions_g_km',
    ax=ax,
    order=df.groupby('make')['co2_emissions_g_km'].mean().sort_values(ascending=False).index,
    capsize=0.2,
)

# Barras
ax.bar_label(
    ax.containers[0],
    fmt='%.1f',
    rotation=90,
    padding=12,
    size=10,
    weight='bold'
)

# Eixos e Título
ax.set_xlabel('')
plt.xticks(rotation=90)
ax.set_ylim(0, 650)
ax.set_ylabel('')
ax.set_yticks([])
ax.set_title(f'Average {co2_latex} Emissions per Maker (g/km)')

# Personalizações
norm = mcolors.Normalize(
    vmin=df['co2_emissions_g_km'].min(),
    vmax=df['co2_emissions_g_km'].max(),
)

cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
co2_latex = r'CO$_2$'

fig, ax = plt.subplots(figsize=(12, 6))

# Gráfico
sns.barplot(
    data=df,
    x='vehicle_class',
    y='co2_emissions_g_km',
    ax=ax,
    order=df.groupby('vehicle_class')['co2_emissions_g_km'].mean().sort_values(ascending=False).index,
    capsize=0.2,
)

# Barras
ax.bar_label(
    ax.containers[0],
    fmt='%.1f',
    rotation=90,
    padding=12,
    size=10,
    weight='bold'
)

# Eixos e Título
ax.set_xlabel('')
plt.xticks(rotation=90)
ax.set_ylim(0, 450)
ax.set_ylabel('')
ax.set_yticks([])
ax.set_title(f'Average {co2_latex} Emissions per vehicle class (g/km)')

# Personalizações
norm = mcolors.Normalize(
    vmin=df['co2_emissions_g_km'].min(),
    vmax=df['co2_emissions_g_km'].max(),
)

cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
co2_latex = r'CO$_2$'

fig, ax = plt.subplots(figsize=(12, 6))

# Gráfico
sns.barplot(
    data=df,
    x='transmission',
    y='co2_emissions_g_km',
    ax=ax,
    order=df.groupby('transmission')['co2_emissions_g_km'].mean().sort_values(ascending=False).index,
    capsize=0.2,
)

# Barras
ax.bar_label(
    ax.containers[0],
    fmt='%.1f',
    rotation=90,
    padding=12,
    size=10,
    weight='bold'
)

# Eixos e Título
ax.set_xlabel('')
plt.xticks(rotation=90)
ax.set_ylim(0, 650)
ax.set_ylabel('')
ax.set_yticks([])
ax.set_title(f'Average {co2_latex} Emissions per transmission (g/km)')

# Personalizações
norm = mcolors.Normalize(
    vmin=df['co2_emissions_g_km'].min(),
    vmax=df['co2_emissions_g_km'].max(),
)

cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
co2_latex = r'CO$_2$'

fig, ax = plt.subplots(figsize=(12, 6))

# Gráfico
sns.barplot(
    data=df,
    x='fuel_type',
    y='co2_emissions_g_km',
    ax=ax,
    order=df.groupby('fuel_type')['co2_emissions_g_km'].mean().sort_values(ascending=False).index,
    capsize=0.2,
)

# Barras
ax.bar_label(
    ax.containers[0],
    fmt='%.1f',
    rotation=90,
    padding=12,
    size=10,
    weight='bold'
)

# Eixos e Título
ax.set_xlabel('')
plt.xticks(rotation=90)
ax.set_ylim(0, 350)
ax.set_ylabel('')
ax.set_yticks([])
ax.set_title(f'Average {co2_latex} Emissions per fuel type (g/km)')

# Personalizações
norm = mcolors.Normalize(
    vmin=df['co2_emissions_g_km'].min(),
    vmax=df['co2_emissions_g_km'].max(),
)

cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
co2_latex = r'CO$_2$'

fig, ax = plt.subplots(figsize=(12, 6))

# Gráfico
sns.barplot(
    data=df,
    x='model_year',
    y='co2_emissions_g_km',
    ax=ax,
    capsize=0.2,
)

# Barras
ax.bar_label(
    ax.containers[0],
    fmt='%.1f',
    rotation=90,
    padding=12,
    size=10,
    weight='bold'
)

# Eixos e Título
ax.set_xlabel('')
plt.xticks(rotation=90)
ax.set_ylim(0, 350)
ax.set_ylabel('')
ax.set_yticks([])
ax.set_title(f'Average {co2_latex} Emissions per model year (g/km)')

# Personalizações
norm = mcolors.Normalize(
    vmin=df['co2_emissions_g_km'].min(),
    vmax=df['co2_emissions_g_km'].max(),
)

cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
pd.crosstab(df['model_year'], df['vehicle_class'])
# Out:
# vehicle_class  Compact  Full-size  Mid-size  Minicompact  Minivan  \
# model_year
# 2005               146         45       114           74       33
# 2006               137         56       111           37       35
# 2007               116         54       139           47       34
# 2008               148         63       134           49       22
# 2009               152         68       125           43       16
# 2010               144         77       120           41       14
# 2011               128         71       132           53       14
# 2012               137         81       132           76       16
# 2013               175         77       157           53       15
# 2014               172         86       179           47       14
# 2015               186         93       180           59       15
# 2016               181         90       188           52       12
# 2017               159         82       162           44       12
# 2018               122        109       158           53       11
# 2019               106        101       145           56        9
# 2020               109         78       128           23        8
# 2021                85         65       116           30        7
# 2022                70         65       118           45        7
# 2023                63         48       114           22        7
# 2024                50         36        84           49        7
# 2025                53         29        67           28        8
#
# vehicle_class  Pickup truck: Small  Pickup truck: Standard  \
# model_year
# 2005                             0                     127
# 2006                             0                     141
# 2007                             0                     154
# 2008                            52                      72
# 2009                            59                      95
# 2010                            54                      73
# 2011                            51                      85
# 2012                            43                      79
# 2013                            12                      84
# 2014                            12                      60
# 2015                            22                      49
# 2016                            26                      59
# 2017                            28                      75
# 2018                            27                      97
# 2019                            25                      99
# 2020                            19                      91
# 2021                            17                     115
# 2022                            20                     113
# 2023                            17                      97
# 2024                            19                      79
# 2025                             8                      74
#
# vehicle_class  Special purpose vehicle  Sport utility vehicle  \
# model_year
# 2005                                 0                    224
# 2006                                 0                    221
# 2007                                 0                    240
# 2008                                 0                    267
# 2009                                 0                    268
# 2010                                 1                    251
# 2011                                 1                    270
# 2012                                 2                    239
# 2013                                 5                      0
# 2014                                 7                      0
# 2015                                 9                      0
# 2016                                17                      0
# 2017                                10                      0
# 2018                                10                      0
# 2019                                14                      0
# 2020                                13                      0
# 2021                                13                      0
# 2022                                12                      0
# 2023                                 5                      0
# 2024                                 0                      0
# 2025                                 0                      0
#
# vehicle_class  Sport utility vehicle: Small  Sport utility vehicle: Standard  \
# model_year
# 2005                                      0                                0
# 2006                                      0                                0
# 2007                                      0                                0
# 2008                                      0                                0
# 2009                                      0                                0
# 2010                                      0                                0
# 2011                                      0                                0
# 2012                                      0                                0
# 2013                                    139                              109
# 2014                                    156                              110
# 2015                                    179                               98
# 2016                                    180                              106
# 2017                                    174                              102
# 2018                                    177                              103
# 2019                                    174                              111
# 2020                                    188                              122
# 2021                                    204                              143
# 2022                                    208                              156
# 2023                                    195                              139
# 2024                                    184                              131
# 2025                                    179                              136
#
# vehicle_class  Station wagon: Mid-size  Station wagon: Small  Subcompact  \
# model_year
# 2005                                38                    54          87
# 2006                                28                    53          78
# 2007                                32                    44          83
# 2008                                18                    43         100
# 2009                                13                    56          99
# 2010                                 9                    63          98
# 2011                                 4                    59         104
# 2012                                 5                    50         102
# 2013                                 3                    47          96
# 2014                                 6                    36          64
# 2015                                 8                    35          92
# 2016                                 7                    37          76
# 2017                                 8                    45          93
# 2018                                10                    39          96
# 2019                                 9                    37          98
# 2020                                 8                    25          95
# 2021                                 9                    20          83
# 2022                                 8                    19          79
# 2023                                 9                    14          75
# 2024                                 6                    11          63
# 2025                                 4                    15          50
#
# vehicle_class  Two-seater  Van: Cargo  Van: Passenger
# model_year
# 2005                   52          13              12
# 2006                   49          14               8
# 2007                   61          27              12
# 2008                   73          26              12
# 2009                   64          26              12
# 2010                   59          18               8
# 2011                   64          22              27
# 2012                   76          22              31
# 2013                   58          22              30
# 2014                   72          22              25
# 2015                   84           0              19
# 2016                   68           0               7
# 2017                   57           0               7
# 2018                   69           0               2
# 2019                   70           0               2
# 2020                   64           0               4
# 2021                   59           0               4
# 2022                   56           0               0
# 2023                   35           0               0
# 2024                   49           0               0
# 2025                   42           0               0

# %%
pd.crosstab(df['model_year'], df['fuel_type'])
# Out:
# fuel_type   diesel  ethanol  natural_gas  premium_gasoline  reg_gasoline
# model_year
# 2005            14       30            0               432           543
# 2006            12       23            0               389           544
# 2007             5       53            0               429           556
# 2008             5       48            0               480           546
# 2009            10       71            0               439           576
# 2010            14       71            0               408           537
# 2011            15      104            0               421           545
# 2012            16      104            0               432           539
# 2013            19      110            0               429           524
# 2014            23       92            0               435           518
# 2015            30       64            0               501           533
# 2016            21       57            1               461           566
# 2017            15       49            0               439           555
# 2018            28       47            0               484           524
# 2019            27       38            0               491           500
# 2020            20       23            0               489           443
# 2021            29       14            0               470           457
# 2022            28       14            0               486           448
# 2023            20       16            0               414           390
# 2024            18        6            0               409           335
# 2025            13        3            0               377           300

# %%
df[df['fuel_type'] == 'natural_gas']
# Out:
#        model_year       make vehicle_class  engine_size_l  cylinders  \
# 11925        2016  Chevrolet      Mid-size            3.6          6
#
#       transmission    fuel_type  city_l_100_km  highway_l_100_km  \
# 11925           AS  natural_gas           15.2               9.5
#
#        combined_l_100_km  co2_emissions_g_km  co2_rating  smog_rating  gears
# 11925               12.7                 213         6.0          NaN    6.0

# %%
df = df.drop(df[df['fuel_type'] == 'natural_gas'].index)

df['fuel_type'].value_counts()
# Out:
# fuel_type
# reg_gasoline        10479
# premium_gasoline     9315
# ethanol              1037
# diesel                382
# Name: count, dtype: int64

# %%
pd.crosstab(
    df['model_year'], df['fuel_type'], values=df['co2_emissions_g_km'], aggfunc='mean',
).style.background_gradient(cmap='RdYlGn_r', axis=None)
# Out:
# <style type="text/css">
# #T_b51a0_row0_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_b51a0_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b51a0_row0_col2 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_b51a0_row0_col3 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_b51a0_row1_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b51a0_row1_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_b51a0_row1_col2, #T_b51a0_row2_col0, #T_b51a0_row3_col2, #T_b51a0_row5_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_b51a0_row1_col3, #T_b51a0_row9_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_b51a0_row2_col1 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_b51a0_row2_col2, #T_b51a0_row4_col1 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_b51a0_row2_col3, #T_b51a0_row16_col1 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_b51a0_row3_col0, #T_b51a0_row6_col1 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_b51a0_row3_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_b51a0_row3_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_b51a0_row4_col0 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_b51a0_row4_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_b51a0_row4_col3 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_b51a0_row5_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_b51a0_row5_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_b51a0_row5_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_b51a0_row6_col0 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_b51a0_row6_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_b51a0_row6_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_b51a0_row7_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_b51a0_row7_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_b51a0_row7_col2 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_b51a0_row7_col3 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_b51a0_row8_col0 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_b51a0_row8_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_b51a0_row8_col2, #T_b51a0_row18_col0, #T_b51a0_row20_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_b51a0_row8_col3 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_b51a0_row9_col0 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_b51a0_row9_col2 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_b51a0_row9_col3 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_b51a0_row10_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_b51a0_row10_col1, #T_b51a0_row12_col2, #T_b51a0_row15_col0 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_b51a0_row10_col2 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_b51a0_row10_col3, #T_b51a0_row11_col3, #T_b51a0_row13_col0, #T_b51a0_row15_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_b51a0_row11_col0 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_b51a0_row11_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_b51a0_row11_col2 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_b51a0_row12_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_b51a0_row12_col1, #T_b51a0_row13_col2, #T_b51a0_row14_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_b51a0_row12_col3, #T_b51a0_row19_col3 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_b51a0_row13_col1, #T_b51a0_row15_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_b51a0_row13_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_b51a0_row14_col0 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_b51a0_row14_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_b51a0_row14_col3 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_b51a0_row15_col1 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_b51a0_row16_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_b51a0_row16_col2, #T_b51a0_row17_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_b51a0_row16_col3, #T_b51a0_row18_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_b51a0_row17_col0 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_b51a0_row17_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_b51a0_row17_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_b51a0_row18_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_b51a0_row18_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_b51a0_row19_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_b51a0_row19_col1 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_b51a0_row19_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_b51a0_row20_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_b51a0_row20_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_b51a0_row20_col3 {
#   background-color: #78c565;
#   color: #000000;
# }
# </style>
# <table id="T_b51a0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >fuel_type</th>
#       <th id="T_b51a0_level0_col0" class="col_heading level0 col0" >diesel</th>
#       <th id="T_b51a0_level0_col1" class="col_heading level0 col1" >ethanol</th>
#       <th id="T_b51a0_level0_col2" class="col_heading level0 col2" >premium_gasoline</th>
#       <th id="T_b51a0_level0_col3" class="col_heading level0 col3" >reg_gasoline</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b51a0_level0_row0" class="row_heading level0 row0" >2005</th>
#       <td id="T_b51a0_row0_col0" class="data row0 col0" >215.000000</td>
#       <td id="T_b51a0_row0_col1" class="data row0 col1" >338.666667</td>
#       <td id="T_b51a0_row0_col2" class="data row0 col2" >299.574074</td>
#       <td id="T_b51a0_row0_col3" class="data row0 col3" >292.445672</td>
#     </tr>
#     <tr>
#       <th id="T_b51a0_level0_row1" class="row_heading level0 row1" >2006</th>
#       <td id="T_b51a0_row1_col0" class="data row1 col0" >196.750000</td>
#       <td id="T_b51a0_row1_col1" class="data row1 col1" >330.826087</td>
#       <td id="T_b51a0_row1_col2" class="data row1 col2" >297.133676</td>
#       <td id="T_b51a0_row1_col3" class="data row1 col3" >291.117647</td>
#     </tr>
#     <tr>
#       <th id="T_b51a0_level0_row2" class="row_heading level0 row2" >2007</th>
#       <td id="T_b51a0_row2_col0" class="data row2 col0" >297.400000</td>
#       <td id="T_b51a0_row2_col1" class="data row2 col1" >318.113208</td>
#       <td id="T_b51a0_row2_col2" class="data row2 col2" >296.916084</td>
#       <td id="T_b51a0_row2_col3" class="data row2 col3" >287.377698</td>
#     </tr>
#     <tr>
#       <th id="T_b51a0_level0_row3" class="row_heading level0 row3" >2008</th>
#       <td id="T_b51a0_row3_col0" class="data row3 col0" >300.200000</td>
#       <td id="T_b51a0_row3_col1" class="data row3 col1" >310.083333</td>
#       <td id="T_b51a0_row3_col2" class="data row3 col2" >297.243750</td>
#       <td id="T_b51a0_row3_col3" class="data row3 col3" >281.556777</td>
#     </tr>
#     <tr>
#       <th id="T_b51a0_level0_row4" class="row_heading level0 row4" >2009</th>
#       <td id="T_b51a0_row4_col0" class="data row4 col0" >251.300000</td>
#       <td id="T_b51a0_row4_col1" class="data row4 col1" >297.070423</td>
#       <td id="T_b51a0_row4_col2" class="data row4 col2" >301.733485</td>
#       <td id="T_b51a0_row4_col3" class="data row4 col3" >274.781250</td>
#     </tr>
#     <tr>
#       <th id="T_b51a0_level0_row5" class="row_heading level0 row5" >2010</th>
#       <td id="T_b51a0_row5_col0" class="data row5 col0" >248.214286</td>
#       <td id="T_b51a0_row5_col1" class="data row5 col1" >297.507042</td>
#       <td id="T_b51a0_row5_col2" class="data row5 col2" >298.546569</td>
#       <td id="T_b51a0_row5_col3" class="data row5 col3" >260.620112</td>
#     </tr>
#     <tr>

# %%
fig, ax = plt.subplots(figsize=(6,6))

sns.histplot(data=df, x='city_l_100_km', kde=True, ax=ax, label='City')
sns.histplot(data=df, x='highway_l_100_km', kde=True, ax=ax, label='Highway')

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x='combined_l_100_km',
    y='co2_emissions_g_km',
    ax=ax,
    hue='fuel_type'
)

plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x='combined_l_100_km',
    y='co2_emissions_g_km',
    ax=ax,
    hue='transmission'
)

plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x='engine_size_l',
    y='co2_emissions_g_km',
    ax=ax,
    hue='fuel_type'
)

plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x='combined_l_100_km',
    y='co2_emissions_g_km',
    ax=ax,
    hue='vehicle_class'
)

ax.legend(loc='upper left', bbox_to_anchor=(0, 1.2), ncol=4, bbox_transform=fig.transFigure)

plt.show()

# %%
class_map = {
    'Two-seater': 'car',
    'Minicompact': 'car',
    'Subcompact': 'car',
    'Compact': 'car',
    'Mid-size': 'car',
    'Full-size': 'car',
    'Station wagon: Small': 'station_wagon',
    'Station wagon: Mid-size': 'station_wagon',
    'Pickup truck: Small': 'pickup_truck',
    'Pickup truck: Standard': 'pickup_truck',
    'Sport utility vehicle': 'suv',
    'Sport utility vehicle: Small': 'suv',
    'Sport utility vehicle: Standard': 'suv',
    'Minivan': 'van',
    'Van: Cargo': 'van',
    'Van: Passenger': 'van',
    'Special purpose vehicle': 'special_purpose'
}

df['vehicle_class_grouped'] = df['vehicle_class'].map(class_map)

df['vehicle_class_grouped'].value_counts(dropna=False)
# Out:
# vehicle_class_grouped
# car                10988
# suv                 5883
# pickup_truck        2429
# station_wagon       1044
# van                  750
# special_purpose      119
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x='combined_l_100_km',
    y='co2_emissions_g_km',
    ax=ax,
    hue='vehicle_class_grouped'
)

ax.legend(loc='upper left', bbox_to_anchor=(0, 1.2), ncol=3, bbox_transform=fig.transFigure)

plt.show()

# %%
pd.crosstab(df['vehicle_class_grouped'], df['fuel_type'])
# Out:
# fuel_type              diesel  ethanol  premium_gasoline  reg_gasoline
# vehicle_class_grouped
# car                       104      197              6876          3811
# pickup_truck              111      332               126          1860
# special_purpose             0       15                21            83
# station_wagon              28        1               457           558
# suv                       139      295              1832          3617
# van                         0      197                 3           550

# %%
df = df.drop(columns=[
        'make',
        'co2_rating',
        'smog_rating',
        'gears',
        'vehicle_class'
    ]
)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21213 entries, 0 to 21213
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_year             21213 non-null  int64
#  1   engine_size_l          21213 non-null  float64
#  2   cylinders              21213 non-null  int64
#  3   transmission           21213 non-null  object
#  4   fuel_type              21213 non-null  object
#  5   city_l_100_km          21213 non-null  float64
#  6   highway_l_100_km       21213 non-null  float64
#  7   combined_l_100_km      21213 non-null  float64
#  8   co2_emissions_g_km     21213 non-null  int64
#  9   vehicle_class_grouped  21213 non-null  object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 1.8+ MB

# %%
sns.pairplot(
    df,
    kind='reg',
    diag_kind='kde',
    plot_kws={'line_kws': {'color': 'red'}, 'scatter_kws': {'alpha': 0.25}}
)

# %%
df.nunique()
# Out:
# model_year                21
# engine_size_l             61
# cylinders                  9
# transmission               5
# fuel_type                  4
# city_l_100_km            238
# highway_l_100_km         168
# combined_l_100_km        207
# co2_emissions_g_km       376
# vehicle_class_grouped      6
# dtype: int64

# %%
df['engine_size_l'].value_counts(bins=4).sort_index()
# Out:
# (0.791, 2.7]    8723
# (2.7, 4.6]      8307
# (4.6, 6.5]      3982
# (6.5, 8.4]       201
# Name: count, dtype: int64

# %%
df['engine_size_l_class'] = pd.cut(
    df['engine_size_l'],
    bins=[-np.inf, 2.0, 4.0, 6.0, np.inf],
    labels=['up_to_2', 'up_to_4', 'up_to_6', 'more_than_6'],
)

df['engine_size_l_class'].value_counts().sort_index()
# Out:
# engine_size_l_class
# up_to_2         5323
# up_to_4        10711
# up_to_6         4325
# more_than_6      854
# Name: count, dtype: int64

# %%
df['cylinders'].value_counts()
# Out:
# cylinders
# 4     8013
# 6     7168
# 8     4754
# 12     468
# 5      397
# 3      214
# 10     168
# 16      17
# 2       14
# Name: count, dtype: int64

# %%
df['cylinders_class'] = pd.cut(
    df['cylinders'],
    bins=[-np.inf, 4, 6, 8, np.inf],
    labels=['up_to_4', 'up_to_6', 'up_to_8', 'more_than_6'],
)

df['cylinders_class'].value_counts().sort_index()
# Out:
# cylinders_class
# up_to_4        8241
# up_to_6        7565
# up_to_8        4754
# more_than_6     653
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21213 entries, 0 to 21213
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_year             21213 non-null  int64
#  1   engine_size_l          21213 non-null  float64
#  2   cylinders              21213 non-null  int64
#  3   transmission           21213 non-null  object
#  4   fuel_type              21213 non-null  object
#  5   city_l_100_km          21213 non-null  float64
#  6   highway_l_100_km       21213 non-null  float64
#  7   combined_l_100_km      21213 non-null  float64
#  8   co2_emissions_g_km     21213 non-null  int64
#  9   vehicle_class_grouped  21213 non-null  object
#  10  engine_size_l_class    21213 non-null  category
#  11  cylinders_class        21213 non-null  category
# dtypes: category(2), float64(4), int64(3), object(3)
# memory usage: 1.8+ MB

# %%
df = df.drop(columns=['engine_size_l', 'cylinders'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21213 entries, 0 to 21213
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_year             21213 non-null  int64
#  1   transmission           21213 non-null  object
#  2   fuel_type              21213 non-null  object
#  3   city_l_100_km          21213 non-null  float64
#  4   highway_l_100_km       21213 non-null  float64
#  5   combined_l_100_km      21213 non-null  float64
#  6   co2_emissions_g_km     21213 non-null  int64
#  7   vehicle_class_grouped  21213 non-null  object
#  8   engine_size_l_class    21213 non-null  category
#  9   cylinders_class        21213 non-null  category
# dtypes: category(2), float64(3), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df.to_parquet(DADOS_TRATADOS, index=False)
